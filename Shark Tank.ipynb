# %%
url = 'https://www.serialupdates.me/shark-tank-india-investors-names-sony-tv-new-show-entrepreneurs-list/'

# %%
import os

# %%
os.chdir('C:\Scripting')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests

# %%
browser = webdriver.Firefox()

# %%
browser.get(url)

# %%
html = browser.page_source

# %%
soup = BeautifulSoup(html,'html.parser')

# %%
soup.select('figure.wp-block-table.is-style-stripes')[1].find_all('thead')[0].find_all('th')[0].text.strip()
# Out:
# 'Sr No.'

# %%
table = soup.select('figure.wp-block-table.is-style-stripes')[1]

# %%
thead = [i.text.strip() for i in table.find_all('th')]
thead
# Out:
# ['Sr No.',
#  'Entrepreneur Name',
#  'From',
#  'Business',
#  'Deal',
#  'Original Ask',
#  'Final Offer',
#  'Investors']

# %%
import pandas as pd

# %%
def shark():
    thead = [i.text.strip() for i in table.find_all('th')]
    data=[]
    for a in soup.select('figure.wp-block-table.is-style-stripes')[1].tbody.find_all('tr'):
        data.append([i.text.strip() for i in a.find_all('td')])
    df = pd.DataFrame(data)
    df.columns = thead
    return df

# %%
df1 = shark()
df1.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ed8fe">
#   <thead>
#     <tr>
#       <th id="T_ed8fe_level0_col0" class="col_heading level0 col0" >Sr No.</th>
#       <th id="T_ed8fe_level0_col1" class="col_heading level0 col1" >Entrepreneur Name</th>
#       <th id="T_ed8fe_level0_col2" class="col_heading level0 col2" >From</th>
#       <th id="T_ed8fe_level0_col3" class="col_heading level0 col3" >Business</th>
#       <th id="T_ed8fe_level0_col4" class="col_heading level0 col4" >Deal</th>
#       <th id="T_ed8fe_level0_col5" class="col_heading level0 col5" >Original Ask</th>
#       <th id="T_ed8fe_level0_col6" class="col_heading level0 col6" >Final Offer</th>
#       <th id="T_ed8fe_level0_col7" class="col_heading level0 col7" >Investors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ed8fe_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ed8fe_row0_col1" class="data row0 col1" >Aditi Madan (Momo Mami)</td>
#       <td id="T_ed8fe_row0_col2" class="data row0 col2" >Darjeeling</td>
#       <td id="T_ed8fe_row0_col3" class="data row0 col3" >Momos(BluePine Foods)</td>
#       <td id="T_ed8fe_row0_col4" class="data row0 col4" >Deal</td>
#       <td id="T_ed8fe_row0_col5" class="data row0 col5" >₹50 lakhs5% Equity</td>
#       <td id="T_ed8fe_row0_col6" class="data row0 col6" >₹75 lakhs 16% Equity</td>
#       <td id="T_ed8fe_row0_col7" class="data row0 col7" >Ashneer, Aman, Vineeta</td>
#     </tr>
#     <tr>
#       <td id="T_ed8fe_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ed8fe_row1_col1" class="data row1 col1" >Rutvij Dasadia</td>
#       <td id="T_ed8fe_row1_col2" class="data row1 col2" >Ahmedabad</td>
#       <td id="T_ed8fe_row1_col3" class="data row1 col3" >Electric Scooters (Booz)</td>
#       <td id="T_ed8fe_row1_col4" class="data row1 col4" >Deal</td>
#       <td id="T_ed8fe_row1_col5" class="data row1 col5" >₹40 lakhs15% Equity</td>
#       <td id="T_ed8fe_row1_col6" class="data row1 col6" >₹40 lakhs50% Equity</td>
#       <td id="T_ed8fe_row1_col7" class="data row1 col7" >Ashneer, Vineeta</td>
#     </tr>
#     <tr>
#       <td id="T_ed8fe_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ed8fe_row2_col1" class="data row2 col1" >Riya Khattar</td>
#       <td id="T_ed8fe_row2_col2" class="data row2 col2" >New Delhi</td>
#       <td id="T_ed8fe_row2_col3" class="data row2 col3" >Outfit(Heart Up My Sleeves)</td>
#       <td id="T_ed8fe_row2_col4" class="data row2 col4" >Deal</td>
#       <td id="T_ed8fe_row2_col5" class="data row2 col5" >₹25 lakhs 10% Equity</td>
#       <td id="T_ed8fe_row2_col6" class="data row2 col6" >₹25 lakhs30% Equity</td>
#       <td id="T_ed8fe_row2_col7" class="data row2 col7" >Anupam, Vineeta</td>
#     </tr>
#     <tr>
#       <td id="T_ed8fe_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ed8fe_row3_col1" class="data row3 col1" >Anish and Sagar</td>
#       <td id="T_ed8fe_row3_col2" class="data row3 col2" >Delhi</td>
#       <td id="T_ed8fe_row3_col3" class="data row3 col3" >Popped Chips(Tagz Foods)</td>
#       <td id="T_ed8fe_row3_col4" class="data row3 col4" >Deal</td>
#       <td id="T_ed8fe_row3_col5" class="data row3 col5" >₹70 lakhs 1% Equity</td>
#       <td id="T_ed8fe_row3_col6" class="data row3 col6" >₹70 lakhs  2.75% Equity</td>
#       <td id="T_ed8fe_row3_col7" class="data row3 col7" >Ashneer</td>
#     </tr>
#     <tr>
#       <td id="T_ed8fe_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_ed8fe_row4_col1" class="data row4 col1" >Singh Family</td>
#       <td id="T_ed8fe_row4_col2" class="data row4 col2" >Punjab</td>
#       <td id="T_ed8fe_row4_col3" class="data row4 col3" >Brain Training(Head and Heart)</td>
#       <td id="T_ed8fe_row4_col4" class="data row4 col4" >No Deal</td>
#       <td id="T_ed8fe_row4_col5" class="data row4 col5" >₹50 lakhs 5% Equity</td>
#       <td id="T_ed8fe_row4_col6" class="data row4 col6" >No Offer</td>
#       <td id="T_ed8fe_row4_col7" class="data row4 col7" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_ed8fe_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_ed8fe_row5_col1" class="data row5 col1" >Pandurang Taware</td>
#       <td id="T_ed8fe_row5_col2" class="data row5 col2" >Maharashtra</td>
#       <td id="T_ed8fe_row5_col3" class="data row5 col3" >Agri Tourism</td>
#       <td id="T_ed8fe_row5_col4" class="data row5 col4" >No Deal</td>
#       <td id="T_ed8fe_row5_col5" class="data row5 col5" >₹50 lakhs5% Equity</td>
#       <td id="T_ed8fe_row5_col6" class="data row5 col6" >No Offer</td>
#       <td id="T_ed8fe_row5_col7" class="data row5 col7" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_ed8fe_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_ed8fe_row6_col1" class="data row6 col1" >Rubal and Srishti</td>
#       <td id="T_ed8fe_row6_col2" class="data row6 col2" >Delhi</td>
#       <td id="T_ed8fe_row6_col3" class="data row6 col3" >Fruit Checker(qZense Labs)</td>
#       <td id="T_ed8fe_row6_col4" class="data row6 col4" >No Deal</td>
#       <td id="T_ed8fe_row6_col5" class="data row6 col5" >₹1 crore 0.5% Equity</td>
#       <td id="T_ed8fe_row6_col6" class="data row6 col6" >₹1 crore5% Equity</td>
#       <td id="T_ed8fe_row6_col7" class="data row6 col7" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_ed8fe_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_ed8fe_row7_col1" class="data row7 col1" >Siddhant Tawarawala</td>
#       <td id="T_ed8fe_row7_col2" class="data row7 col2" >Maharashtra</td>
#       <td id="T_ed8fe_row7_col3" class="data row7 col3" >Urine Bag(Peeschute)</td>
#       <td id="T_ed8fe_row7_col4" class="data row7 col4" >Deal</td>
#       <td id="T_ed8fe_row7_col5" class="data row7 col5" >₹75 lakhs 4% Equity</td>
#       <td id="T_ed8fe_row7_col6" class="data row7 col6" >₹75 lakhs6% Equity</td>
#       <td id="T_ed8fe_row7_col7" class="data row7 col7" >Aman</td>
#     </tr>
#     <tr>
#       <td id="T_ed8fe_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_ed8fe_row8_col1" class="data row8 col1" >Siddharth and Vinay</td>
#       <td id="T_ed8fe_row8_col2" class="data row8 col2" >Bangalore</td>
#       <td id="T_ed8fe_row8_col3" class="data row8 col3" >Energy Drink(NOCD)</td>
#       <td id="T_ed8fe_row8_col4" class="data row8 col4" >Deal</td>
#       <td id="T_ed8fe_row8_col5" class="data row8 col5" >₹50 lakhs2% Equity</td>
#       <td id="T_ed8fe_row8_col6" class="data row8 col6" >₹10 lakhs10% Equity ₹30 lakhs Debt</td>
#       <td id="T_ed8fe_row8_col7" class="data row8 col7" >Vineeta</td>
#     </tr>
#     <tr>
#       <td id="T_ed8fe_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_ed8fe_row9_col1" class="data row9 col1" >Angad and Kanika</td>
#       <td id="T_ed8fe_row9_col2" class="data row9 col2" >New Delhi</td>
#       <td id="T_ed8fe_row9_col3" class="data row9 col3" >Skincare Serum(Cos IQ)</td>
#       <td id="T_ed8fe_row9_col4" class="data row9 col4" >Deal</td>
#       <td id="T_ed8fe_row9_col5" class="data row9 col5" >₹50 lakhs7% Equity</td>
#       <td id="T_ed8fe_row9_col6" class="data row9 col6" >₹50 lakhs25% Equity</td>
#       <td id="T_ed8fe_row9_col7" class="data row9 col7" >Anupam, Vineeta</td>
#     </tr>
#     <tr>
#       <td id="T_ed8fe_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_ed8fe_row10_col1" class="data row10 col1" >Kalpana and Uma Jha</td>
#       <td id="T_ed8fe_row10_col2" class="data row10 col2" >Bihar</td>
#       <td id="T_ed8fe_row10_col3" class="data row10 col3" >Pickles(JhaJi Store)</td>
#       <td id="T_ed8fe_row10_col4" class="data row10 col4" >No Deal</td>
#       <td id="T_ed8fe_row10_col5" class="data row10 col5" >₹50 lakhs10% Equity</td>
#       <td id="T_ed8fe_row10_col6" class="data row10 col6" >No Offer</td>
#       <td id="T_ed8fe_row10_col7" class="data row10 col7" >N/A</td>
#     </tr>
#     <tr>
#       <td id="T_ed8fe_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_ed8fe_row11_col1" class="data row11 col1" >Sulay Lavsi</td>
#       <td id="T_ed8fe_row11_col2" class="data row11 col2" >Ahmedabad</td>
#       <td id="T_ed8fe_row11_col3" class="data row11 col3" >Underwears(Bummer)</td>
#       <td id="T_ed8fe_row11_col4" class="data row11 col4" >Deal</td>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No.             117 non-null    object
#  1   Entrepreneur Name  117 non-null    object
#  2   From               117 non-null    object
#  3   Business           117 non-null    object
#  4   Deal               117 non-null    object
#  5   Original Ask       117 non-null    object
#  6   Final Offer        117 non-null    object
#  7   Investors          117 non-null    object
# dtypes: object(8)
# memory usage: 7.4+ KB

# %%
df1["Sr No."] = pd.to_numeric(df1["Sr No."])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No.             117 non-null    int64
#  1   Entrepreneur Name  117 non-null    object
#  2   From               117 non-null    object
#  3   Business           117 non-null    object
#  4   Deal               117 non-null    object
#  5   Original Ask       117 non-null    object
#  6   Final Offer        117 non-null    object
#  7   Investors          117 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 7.4+ KB

# %%
df1.to_csv("Shark Tank Investor Details.csv",index=False)
